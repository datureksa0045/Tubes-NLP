# %%
# pip install pandas deep-translator tqdm

import pandas as pd
from deep_translator import GoogleTranslator
from tqdm import tqdm

# ======================================
# BACA FILE CSV
# ======================================

df = pd.read_csv("chunk_6.csv")

# ======================================
# CEK KOLOM
# ======================================

print(df.columns.tolist())

# ======================================
# INISIALISASI TRANSLATOR
# ======================================

translator = GoogleTranslator(
    source='en',
    target='id'
)

# ======================================
# FUNGSI TRANSLASI
# ======================================

def translate_text(text):
    try:
        if pd.isna(text):
            return ""
        return translator.translate(str(text))
    except Exception as e:
        print(f"Error: {e}")
        return text

# ======================================
# TRANSLASI KOLOM NEWS TITLE
# ======================================

tqdm.pandas(desc="Menerjemahkan")

df["News Title Indonesia"] = df["News Title"].progress_apply(
    translate_text
)

# ======================================
# SIMPAN HASIL
# ======================================

df.to_csv(
    "News_Title_Indonesia.csv",
    index=False,
    encoding="utf-8-sig"
)

print("\nTranslasi selesai!")
print(df.head())
# Out:
# ['No', 'News Title', 'Category']
# Menerjemahkan:  39%|███▉      | 3843/9740 [1:05:29<18:25:41, 11.25s/it]
# Error: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Menerjemahkan:  45%|████▍     | 4345/9740 [1:14:16<1:30:49,  1.01s/it]
# Error: Nuance Communications explores sale options --> No translation was found using the current translator. Try another translator?
# Menerjemahkan:  51%|█████     | 4989/9740 [1:25:50<1:33:50,  1.19s/it]
# Error: Chemists Expand Nature's Genetic Alphabet --> No translation was found using the current translator. Try another translator?
# Menerjemahkan:  51%|█████▏    | 4997/9740 [1:26:00<1:44:01,  1.32s/it]
# Error: Consumer Confidence Bounces Back in March --> No translation was found using the current translator. Try another translator?
# Menerjemahkan:  51%|█████▏    | 5000/9740 [1:26:03<1:32:04,  1.17s/it]
# Error: Samsung says it is closer to flexible electronics after graphene breakthrough --> No translation was found using the current translator. Try another translator?
# Menerjemahkan:  51%|█████▏    | 5013/9740 [1:26:15<1:19:59,  1.02s/it]
# Error: DISH Network Corp (DISH) news: Report: Dish Network pushing for merger talks  ... --> No translation was found using the current translator. Try another translator?
# Menerjemahkan: 100%|██████████| 9740/9740 [2:57:12<00:00,  1.09s/it]
# Translasi selesai!
#       No                                         News Title       Category  \
# 0  42932  Movie review: Raunchy comedy 'Neighbors' is ne...  Entertainment
# 1  39585  2014 Mercedes-Benz B-Class Electric Drive Gets...     Technology
# 2  17721  'I Am Alive And Well': Seinfeld Star Wayne Kni...  Entertainment
# 3  30712  Titanfall PC's 48GB install size explained by ...     Technology
# 4  49189  Look Out Ibiza: Kendall Jenner & Kim Kardashia...  Entertainment
#
#                                 News Title Indonesia
# 0  Ulasan film: Komedi cabul 'Neighbors' hampir lucu
# 1  Mercedes-Benz B-Class Electric Drive 2014 Dapa...
# 2  'I Am Alive And Well': Bintang Seinfeld Wayne ...
# 3  Ukuran instalasi Titanfall PC 48GB dijelaskan ...
# 4  Awas Ibiza: Kendall Jenner & Kim Kardashian Je...
