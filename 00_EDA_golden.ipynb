# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("golden_dataset/random_dataset (category).csv", usecols=["Tweet", "Category"])

# %%
df
# Out:
#                                                  Tweet      Category
# 0    Selamat pagi. Bangun tidur dan mendapati $1 se...       Economy
# 1    Saat Anda berbicara tentang sebuah serial, seb...  Entertaiment
# 2    Bisnis apa yang aman untuk dimulai ketika pere...       Economy
# 3    Meski Purbaya kerap mengklaim keadaan baik-bai...       Economy
# 4                  Dia tertipu trik tertua dan diculik  Entertaiment
# ..                                                 ...           ...
# 474  Integrasi Jaringan XLSmart Capai 70%  Sinyal 5...    Technology
# 475       itulah yang saya rasakan tentang The Sandman  Entertaiment
# 476                Apakah ini foto dari musim terbaru?  Entertaiment
# 477                      TEMAN-TEMAN... SAYA BARU TAHU  Entertaiment
# 478  SpaceX Ternyata Bakar Duit Besar-besaran dan R...    Technology
#
# [479 rows x 2 columns]

# %%
# Hitung jumlah data tiap kategori
category_counts = df["Category"].value_counts()

# Visualisasi
plt.figure(figsize=(8,5))
bars = plt.bar(category_counts.index, category_counts.values)

# Menampilkan jumlah di atas bar
for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height(),
        str(int(bar.get_height())),
        ha='center',
        va='bottom',
        fontsize=11
    )

plt.title("Distribution of Tweet Categories")
plt.xlabel("Category")
plt.ylabel("Number of Tweets")
plt.grid(axis='y', linestyle='--', alpha=0.3)

plt.show()
