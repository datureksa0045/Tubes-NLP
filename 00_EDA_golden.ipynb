# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("golden_dataset/random_dataset (category).csv", usecols=["Tweet", "Category"])

# %%
df
# Out:
#                                                  Tweet      Category
# 0         itulah yang saya rasakan tentang The Sandman  Entertaiment
# 1    Kompilasi video kecepatan 4x dari sesi gacha 4...  Entertaiment
# 2    Jadwal MPL ID S17 Week 8 Hari Ini: Dewa United...    Technology
# 3    SALAH SATU PENYEBAB KEMISKINAN BUKAN KARENA KE...       Economy
# 4    bayangkan jika setiap serial animasi meningkat...  Entertaiment
# ..                                                 ...           ...
# 295  Era AI membutuhkan CPU baru. Perkenalkan NVIDI...    Technology
# 296  Pertumbuhan ekonominya tinggi tapi yang tumbuh...       Economy
# 297  Integrasi Jaringan XLSmart Capai 70%  Sinyal 5...    Technology
# 298                    dia benar-benar menjadi ibunya.  Entertaiment
# 299  SpaceX Ternyata Bakar Duit Besar-besaran dan R...    Technology
#
# [300 rows x 2 columns]

# %%
# Hitung jumlah data tiap kategori
category_counts = df["Category"].value_counts()

# Visualisasi
plt.figure(figsize=(8,5))
bars = plt.bar(category_counts.index, category_counts.values)

# Menampilkan jumlah di atas bar
for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height(),
        str(int(bar.get_height())),
        ha='center',
        va='bottom',
        fontsize=11
    )

plt.title("Distribution of Tweet Categories")
plt.xlabel("Category")
plt.ylabel("Number of Tweets")
plt.grid(axis='y', linestyle='--', alpha=0.3)

plt.show()
