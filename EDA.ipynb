# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/dataset.csv', sep=',', index_col=False)

# %%
df = df.drop(columns=["News Title", "No"])

# %%
df = df.rename(columns={
    "News Title Indonesia": "tweet",
    "Category": "category"
})

# %%
cols = list(df.columns)
cols.remove("category")
cols.insert(1, "category")
df = df[cols]

# %%
df.to_csv("dataset_final.csv", index=False)

print(df.head())
print("\nUrutan kolom:")
print(df.columns.tolist())
# Out:
#                                                tweet       category
# 0  Nest Protect mendapat penarikan kembali dan pe...     Technology
# 1                 PS4 vs. Xbox One: 6 Bulan Kemudian     Technology
# 2                                   Pertemuan Gereja  Entertainment
# 3  Facebook: Kami "tidak punya rencana" untuk men...     Technology
# 4  Kudeta di Thailand memicu pembatalan pemesanan...  Entertainment
#
# Urutan kolom:
# ['tweet', 'category']

# %%
df
# Out:
#                                                    tweet       category
# 0      Nest Protect mendapat penarikan kembali dan pe...     Technology
# 1                     PS4 vs. Xbox One: 6 Bulan Kemudian     Technology
# 2                                       Pertemuan Gereja  Entertainment
# 3      Facebook: Kami "tidak punya rencana" untuk men...     Technology
# 4      Kudeta di Thailand memicu pembatalan pemesanan...  Entertainment
# ...                                                  ...            ...
# 48699                         Keraguan atas Garth's Gigs  Entertainment
# 48700  Rata-rata suku bunga hipotek 30 tahun AS turun...        Economy
# 48701  NY menjadi pusat perebutan undang-undang pelab...        Economy
# 48702  Angelina Jolie menyempurnakan suaranya untuk M...  Entertainment
# 48703  Pejabat: Bintang reality TV Benzino ditembak o...  Entertainment
#
# [48704 rows x 2 columns]
