# %% [markdown]
# # Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Configuration

# %%
SCENARIO = 4

"""
1 : TF-IDF + Naive Bayes
2 : TF-IDF + SVM
3 : FastText + SVM
4 : IndoBERT
"""
# Out:
# '\n1 : TF-IDF + Naive Bayes\n2 : TF-IDF + SVM\n3 : FastText + SVM\n4 : IndoBERT\n'

# %%
SCENARIO_CONFIG = {

    1: {
        "name": "TF-IDF + Naive Bayes",
        "file": "results/training/tfidf_nb_results.csv"
    },

    2: {
        "name": "TF-IDF + SVM",
        "file": "results/training/tfidf_svm_results.csv"
    },

    3: {
        "name": "FastText + SVM",
        "file": "results/training/fasttext_svm_results.csv"
    },

    4: {
        "name": "IndoBERT",
        "file": "results/training/indobert_results.csv"
    }

}

MODEL_NAME = SCENARIO_CONFIG[SCENARIO]["name"]
RESULT_FILE = SCENARIO_CONFIG[SCENARIO]["file"]

print(MODEL_NAME)
# Out:
# IndoBERT

# %%
results = pd.read_csv(
    RESULT_FILE
)

results
# Out:
#       Model Dataset  Train_Size  Accuracy  Precision    Recall  F1-Score
# 0  IndoBERT     10k        8000  0.907500   0.902627  0.900541  0.901503
# 1  IndoBERT     20k       16000  0.930000   0.926162  0.925004  0.925557
# 2  IndoBERT     30k       24000  0.938667   0.935297  0.933939  0.934593
# 3  IndoBERT     40k       32000  0.937375   0.933357  0.933781  0.933566
# 4  IndoBERT    full       38963  0.940458   0.936602  0.936158  0.936377

# %% [markdown]
# # Visual Result

# %% [markdown]
# ## Accuracy

# %%
plt.figure(figsize=(7,5))

plt.plot(
    results["Train_Size"],
    results["Accuracy"],
    marker="o"
)

plt.xlabel("Training Data Size")
plt.ylabel("Accuracy")

plt.title(
    f"Accuracy - {MODEL_NAME}"
)

plt.grid()

plt.show()

# %% [markdown]
# ## Precision

# %%
plt.figure(figsize=(7,5))

plt.plot(
    results["Train_Size"],
    results["Precision"],
    marker="o"
)

plt.xlabel("Training Data Size")
plt.ylabel("Precision")

plt.title(
    f"Precision - {MODEL_NAME}"
)

plt.grid()

plt.show()

# %% [markdown]
# ## Recall

# %%
plt.figure(figsize=(7,5))

plt.plot(
    results["Train_Size"],
    results["Recall"],
    marker="o"
)

plt.xlabel("Training Data Size")
plt.ylabel("Recall")

plt.title(
    f"Recall - {MODEL_NAME}"
)

plt.grid()

plt.show()

# %% [markdown]
# ## F1

# %%
plt.figure(figsize=(7,5))

plt.plot(
    results["Train_Size"],
    results["F1-Score"],
    marker="o"
)

plt.xlabel("Training Data Size")
plt.ylabel("F1 Score")

plt.title(
    f"F1 Score - {MODEL_NAME}"
)

plt.grid()

plt.show()

# %% [markdown]
# # Best Model

# %%
best = results.loc[
    results["F1-Score"].idxmax()
]

print("=== BEST RESULT ===\n")

print(best)
# Out:
# === BEST RESULT ===
#
# Model         IndoBERT
# Dataset           full
# Train_Size       38963
# Accuracy      0.940458
# Precision     0.936602
# Recall        0.936158
# F1-Score      0.936377
# Name: 4, dtype: object

# %% [markdown]
# # Save Result

# %%
os.makedirs("results/comparisson", exist_ok=True)

OUTPUT = f"results/comparisson/scenario_{SCENARIO}.csv"

results.to_csv(
    OUTPUT,
    index=False
)

print("Saved:", OUTPUT)
# Out:
# Saved: results/comparisson/scenario_4.csv
