# %% [markdown]
# # Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# # Configuration

# %%
SCENARIO = 1

"""
1 : TF-IDF + Naive Bayes
2 : TF-IDF + SVM
3 : FastText + SVM
4 : IndoBERT
"""
# Out:
# '\n1 : TF-IDF + Naive Bayes\n2 : TF-IDF + SVM\n3 : FastText + SVM\n4 : IndoBERT\n'

# %%
SCENARIO_CONFIG = {

    1: {
        "name": "TF-IDF + Naive Bayes",
        "file": "results/training/tfidf_nb_results.csv"
    },

    2: {
        "name": "TF-IDF + SVM",
        "file": "results/training/tfidf_svm_results.csv"
    },

    3: {
        "name": "FastText + SVM",
        "file": "results/training/fasttext_svm_results.csv"
    },

    4: {
        "name": "IndoBERT",
        "file": "results/training/indobert_results.csv"
    }

}

MODEL_NAME = SCENARIO_CONFIG[SCENARIO]["name"]
RESULT_FILE = SCENARIO_CONFIG[SCENARIO]["file"]

print(MODEL_NAME)
# Out:
# TF-IDF + Naive Bayes

# %%
results = pd.read_csv(
    RESULT_FILE
)

results
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 results = pd.read_csv(
#       2     RESULT_FILE
#       3 )
#       5 results
#
# File c:\Users\HP 840 G6\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\HP 840 G6\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\HP 840 G6\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\HP 840 G6\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\HP 840 G6\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/traning/tfidf_nb_results.csv'

# %% [markdown]
# # Visual Result

# %% [markdown]
# ## Accuracy

# %%
plt.figure(figsize=(7,5))

plt.plot(
    results["Train_Size"],
    results["Accuracy"],
    marker="o"
)

plt.xlabel("Training Data Size")
plt.ylabel("Accuracy")

plt.title(
    f"Accuracy - {MODEL_NAME}"
)

plt.grid()

plt.show()

# %% [markdown]
# ## Precision

# %%
plt.figure(figsize=(7,5))

plt.plot(
    results["Train_Size"],
    results["Precision"],
    marker="o"
)

plt.xlabel("Training Data Size")
plt.ylabel("Precision")

plt.title(
    f"Precision - {MODEL_NAME}"
)

plt.grid()

plt.show()

# %% [markdown]
# ## Recall

# %%
plt.figure(figsize=(7,5))

plt.plot(
    results["Train_Size"],
    results["Recall"],
    marker="o"
)

plt.xlabel("Training Data Size")
plt.ylabel("Recall")

plt.title(
    f"Recall - {MODEL_NAME}"
)

plt.grid()

plt.show()

# %% [markdown]
# ## F1

# %%
plt.figure(figsize=(7,5))

plt.plot(
    results["Train_Size"],
    results["F1-Score"],
    marker="o"
)

plt.xlabel("Training Data Size")
plt.ylabel("F1 Score")

plt.title(
    f"F1 Score - {MODEL_NAME}"
)

plt.grid()

plt.show()

# %% [markdown]
# # Best Model

# %%
best = results.loc[
    results["F1-Score"].idxmax()
]

print("=== BEST RESULT ===\n")

print(best)
# Out:
# === BEST RESULT ===
#
# Train_Size    38963.000000
# Accuracy          0.887075
# Precision         0.880959
# Recall            0.879415
# F1-Score          0.880116
# Name: 4, dtype: float64

# %% [markdown]
# # Save Result

# %%
os.makedirs("results/comparisson", exist_ok=True)

OUTPUT = f"results/comparisson/scenario_{SCENARIO}.csv"

results.to_csv(
    OUTPUT,
    index=False
)

print("Saved:", OUTPUT)
# Out:
# Saved: results/comparisson/scenario_3.csv
